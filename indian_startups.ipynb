# %% [markdown]
# # Indian Startup Ecosystem Analysis

# %% [markdown]
# ## Details
# Name : Evans Tetteh Akoto <br>
# email: evans.tetteh@azubiafrica.org <br>
# Team: Prague <br>
# Link to Github Repo - ([GitHub](https://github.com/Tetteh96/indian-startups))
#
#
# Project - Indian Startup Funding

# %% [markdown]
# ##Introduction
# ## Introduction
#
# ### Project Introduction and Objective
# **Objective** - Our team is trying to venture into the Indian startup ecosystem. As the data experts of the team we are supposed to investigate the ecosystem and propose the best course of action.
#
# ### Business & Data Understanding
# **How does Venture Capital Funding Work?** The process entails entrepreneurs pitching an idea to potential investors seeking finances (funding) to start/improve the business in various ways. A business plan is often a requirement for Venture Capitalist to assess the viability of the entrepreneur’s idea. **Invention** and **Innovation** are key concepts related to Venture Capital funding. Roughly 80% of funding goes into building infrastructure needed to grow the business. (Expenses `[manufacturing, sales, marketing]` and Balance Sheet `[working capital & assets]`).
#
# Venture Capital Funding is short-term oriented - it is meant to grow the business to a point where it can be later sold off (to a Corporation or theough IPO). Sometimes the VC wants **equity** (a share of the business). Start-ups (esp. in the new information economy) lack hard assets and can’t therefore access funding from banks (require collateral)
# **Large institutions** are often behind VC funds – insurance companies, pension funds, financial firms, universities. **Angel Investors** who are High net worth individuals are also participants. While screening ideas or after giving funding to businesses, Venture Capitalists can impose restrictions on behaviour of entrepreneurs.
#
# While looking at the **The Indian Venture Capital context**,  we see a booming start-up ecosystem that has become one of the world’s most vibrant and innovative business environments. Country is increasingly being recognized as popular destinations for venture capital (VC) investments. Early-stage investments are seeing particularly strong growth in recent years while Domestic investors are still the most active investor group.
#
# The are several stages of **Startup/Venture Capital Funding** -
# 1. **Seed Funding** - the earliest stage of capital raising process as business hasn't started and is only an idea. It is considered the most risky and complicated as investor doesn’t have enough info to make a decision. Main participants are mostly Angel Investors (appreciate riskier ventures and expect high returns). Management/Soft skills of entrepreneur can determine business success (although modern Tech challenges this view).
# 2. **Series A Fianncing** - A type of equity-based financing (company offers convertible preferred shares). Consists of businesses that already generate revenues but are still in the pre-profit stage. Primary objective of funding is for continued growth. It follows a more formal process – more complete company info, valuation of company done & VC firm does due diligence (progress made since start, management’s efficiency in managing resources). Series A rounds raise approximately $2 million to $15 million and the median Series A funding 2021 = $10 million. ([Investopedia](https://www.investopedia.com/articles/personal-finance/102015/series-b-c-funding-what-it-all-means-and-how-it-works.asp))
# 3. **Series B Financing** - this is the 3rd Stage Start-up financing and the 2nd stage VC financing. Like Series A, it is also equity based. The business is already in middle stages of growth, has a user base and could be generating profit. It is now looking to expand their market. More participants enter at  this stage as they are willing to invest in later stages of growth. The objective of funding here is to take business past development stage, help business scale or meet levels of demand. Most participants here are Venture Capital firms and private equity firms.
#
#
#
# ## Overview of the Data
#
# The dataset available coonsists of the following peices of data;
# 1. Startup Name/Brand
# 2. Year of Founding
# 3. Location/Headquarters of Business
# 4. Sector of the business
# 5. Founders (Owners)
# 6. Investor (assume it’s the VCs)
# 7. Amount of Funding
# 8. Stage (at which business is in while seeking/offered funding)
#
# **Note** - The 2018 Data Lacks some of the above data and has conflict of some data (like currency).

# %% [markdown]
# ##Hypothesis
# **Null Hypothesis** – No factors determine the amount of funding offered to a start-up by venture capitalists in India.
#
# **Alternative Hypothesis** – A range of factors about a start-up(characteristics) such as sector it wants to venture into, use of technology or years its has been in existence, stage of growth and location determine the amount of funding offered to start-ups by venture capitalists in India.

# %% [markdown]
# ##Research Questions
# **Sector**
# 1. What sectors have attracted the largest funding in the last 4 years?
# 2. Who are the major funders of ventures in India in the last 4 years? And what are the major sectors they are directing their funding?
# 3. What are the Maximum, Minimum, Average and Median Funding amounts offered to each sector/ stage of funding and how do they compare?
# 4. What is the trend of financing over the four years, cumulatively (total funding) and in independent sectors? (Monthly and/Yearly Trends)
# **Technology**
# 5. What business technologies have recieved the highest funding or have been funded more over the last four years?
# **Location**
# 6. What locations have received the biggest funding?
# 7. What is the spread of Venture Capital funding in India regionally and how do they compare?
# **Stage**
# 8. Does the stage of the venture affect the amount of funding offered to ventures?
# 9. How many ventures that have got a previous round of financing gone on to successfully raise another stage of financing?
# **Founders**
# 10. Does the number of business owners (entrepreneurs) in a venture determine the amount/likelihood of funding from investors?
# 11. Does the year of founding determine/influence the funding amount?

# %% [markdown]
# ##Installing

# %%
# !pip install -q <lib_001> <lib_002> ...

# %% [markdown]
# ##Importing

# %%
# Data handling
import pandas as pd

# Vizualisation (Matplotlib, Plotly, Seaborn, etc. )
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_style('darkgrid')
#sns.set(font_scale=1.3)

# EDA (pandas-profiling, etc. )
# Feature Processing (Scikit-learn processing, etc. )
from sklearn import preprocessing 

# Machine Learning (Scikit-learn Estimators, Catboost, LightGBM, etc. )
from sklearn.ensemble import RandomForestRegressor 
import lightgbm as lgb
# Hyperparameters Fine-tuning (Scikit-learn hp search, cross-validation, etc. )
...

# Other packages
import os

# %% [markdown]
# ## Data Loading

# %%
df_2018 = pd.read_csv('India Startup Funding/startup_funding2018.csv')
df_2019 = pd.read_csv('India Startup Funding/startup_funding2019.csv')
df_2020 = pd.read_csv('India Startup Funding/startup_funding2020.csv')
df_2021 = pd.read_csv('India Startup Funding/startup_funding2021.csv')

# %% [markdown]
# ##EDA
# ###Data Overview
# ####2018, 2019, 2020 and 20121 Datasets

# %%
df_2018.head(50)
# Out:
#                               Company Name  \
# 0                          TheCollegeFever
# 1                          Happy Cow Dairy
# 2                               MyLoanCare
# 3                              PayMe India
# 4                                 Eunimart
# 5                                   Hasura
# 6                                Tripshelf
# 7                             Hyperdata.IO
# 8                             Freightwalla
# 9                       Microchip Payments
# 10              BizCrum Infotech Pvt. Ltd.
# 11                                 Emojifi
# 12                                   Flock
# 13                               Freshboxx
# 14              Wide Mobility Mechatronics
# 15                                 Pitstop
# 16                                  Mihuru
# 17                                    Fyle
# 18                                AppWharf
# 19        Antariksh Waste Ventures Pvt ltd
# 20                                Cogoport
# ...

# %%
#check for number of columns and rows
df_2018.shape
# Out:
# (526, 6)

# %%
#check info on all columns
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
df_2019.head(50)
# Out:
#                    Company/Brand  Founded HeadQuarter                Sector  \
# 0                 Bombay Shaving      NaN         NaN             Ecommerce
# 1                      Ruangguru   2014.0      Mumbai                Edtech
# 2                       Eduisfun      NaN      Mumbai                Edtech
# 3                       HomeLane   2014.0     Chennai       Interior design
# 4                       Nu Genes   2004.0   Telangana              AgriTech
# 5                       FlytBase      NaN        Pune            Technology
# 6                          Finly      NaN   Bangalore                  SaaS
# 7                       Kratikal   2013.0       Noida            Technology
# 8                      Quantiphi      NaN         NaN             AI & Tech
# 9                       Lenskart   2010.0       Delhi            E-commerce
# 10                    Cub McPaws   2010.0      Mumbai       E-commerce & AR
# ...

# %%
#check for number of columns and rows
df_2019.shape
# Out:
# (89, 9)

# %%
#check info on all columns
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
df_2020.head(50)
# Out:
#                Company/Brand Founded HeadQuarter                    Sector  \
# 0                 Aqgromalin    2019     Chennai                  AgriTech
# 1                   Krayonnz    2019   Bangalore                    EdTech
# 2               PadCare Labs    2018        Pune        Hygiene management
# 3                      NCOME    2020   New Delhi                    Escrow
# 4                 Gramophone    2016      Indore                  AgriTech
# 5                     qZense    2019   Bangalore                  AgriTech
# 6               MyClassboard    2008   Hyderabad                    EdTech
# 7                      Metvy    2018     Gurgaon       Networking platform
# 8                     Rupeek    2015   Bangalore                   FinTech
# 9                  Gig India    2017        Pune             Crowdsourcing
# 10               Slurrp Farm    2016     Gurgaon          Food & Bevarages
# ...

# %%
#check for number of columns and rows
df_2020.shape
# Out:
# (1055, 10)

# %%
#check info on all columns
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
df_2021.head(50)
# Out:
#             Company/Brand  Founded                  HeadQuarter  \
# 0          Unbox Robotics   2019.0                    Bangalore
# 1                  upGrad   2015.0                       Mumbai
# 2             Lead School   2012.0                       Mumbai
# 3                 Bizongo   2015.0                       Mumbai
# 4                FypMoney   2021.0                     Gurugram
# 5           Urban Company   2014.0                    New Delhi
# 6          Comofi Medtech   2018.0                    Bangalore
# 7             Qube Health   2016.0                       Mumbai
# 8                Vitra.ai   2020.0                    Bangalore
# 9                  Taikee   2010.0                       Mumbai
# 10              Fitterfly   2016.0                       Mumbai
# 11              FreeStand   2017.0                    New Delhi
# 12           MyDentalPlan   2014.0                    Bangalore
# 13           Freyr Energy   2014.0                    Hyderabad
# ...

# %%
#check for number of columns and rows
df_2021.shape
# Out:
# (1209, 9)

# %%
#check info on all columns
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# ###Data Processing
# ####Processing 2018, 2019, 2020 and 2021 Datasets

# %%
#2018 Data
df_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %%
#split first words in industry column for use
df_2018['Industry'] = df_2018['Industry'].apply(str)
df_2018['Industry'] = df_2018['Industry'].str.split(',').str[0]
df_2018['Industry'] = df_2018['Industry'].replace("'","",regex=True)

# %%
df_2018['Industry'].head()
# Out:
# 0         Brand Marketing
# 1             Agriculture
# 2                  Credit
# 3      Financial Services
# 4    E-Commerce Platforms
# Name: Industry, dtype: object

# %%
#split first city in location column for use
df_2018['Location'] = df_2018['Location'].apply(str)
df_2018['Location'] = df_2018['Location'].str.split(',').str[0]
df_2018['Location'] = df_2018['Location'].replace("'","",regex=True)

# %%
df_2018['Location'].head()
# Out:
# 0    Bangalore
# 1       Mumbai
# 2      Gurgaon
# 3        Noida
# 4    Hyderabad
# Name: Location, dtype: object

# %%
df_2018['Amount'].value_counts().head(50)
# Out:
# —                 148
# 1000000            24
# 500000             13
# 2000000            12
# ₹50,000,000         9
# ₹20,000,000         8
# 4000000             7
# 5000000             7
# 250000              6
# ₹40,000,000         6
# ₹35,000,000         5
# $100,000            4
# 300000              4
# 1500000             4
# ₹30,000,000         4
# 3000000             4
# 1100000             4
# ₹250,000,000        3
# ₹600,000,000        3
# ₹2,000,000,000      3
# 120000              3
# 30000000            3
# $1,000,000          3
# 200000              3
# ₹70,000,000         3
# 400000              3
# $1,500,000          3
# ₹100,000,000        3
# ₹10,000,000         3
# $100,000,000        3
# 150000              3
# ₹5,000,000          3
# 1300000             3
# $11,000,000         3
# $2,000,000          3
# ₹140,000,000        3
# $10,000,000         2
# $900,000            2
# ₹650,000,000        2
# $50,000,000         2
# $5,000,000          2
# ...

# %%
#create a separate dataframe for amount in rupees
df_2018_Rupees = df_2018[df_2018['Amount'].str.contains('₹')]
df_2018_Rupees['Amount'] = df_2018_Rupees['Amount'].apply(lambda x: x.replace('₹','').replace(',','')).astype('float')
df_2018_Rupees['Amount'] = df_2018_Rupees['Amount']*0.0146

df_2018_Rupees.head()
# Out:
# C:\Users\akoto\AppData\Local\Temp\ipykernel_18328\3008432834.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_Rupees['Amount'] = df_2018_Rupees['Amount'].apply(lambda x: x.replace('₹','').replace(',','')).astype('float')
# C:\Users\akoto\AppData\Local\Temp\ipykernel_18328\3008432834.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_Rupees['Amount'] = df_2018_Rupees['Amount']*0.0146
#        Company Name         Industry Round/Series     Amount   Location  \
# ...

# %%
#remove $ sign amonts then replace with 0
df_2018["Amount"] = df_2018["Amount"].apply(lambda x: x.replace('$','').replace(',','').replace('—', '0'))

# %%
#Subset the data rows which do not contain ruppe sign
df_2018 = df_2018[~df_2018['Amount'].str.contains('₹', na=False)]

# %%
#Merge the cleaned data
df_2018 = pd.concat([df_2018, df_2018_Rupees], ignore_index = True)

#convert the datatype for Amount to float
df_2018['Amount'] = df_2018['Amount'].astype(float)

# %%
df_2018['Amount'].dtypes
# Out:
# dtype('float64')

# %%
df_2018["Funding Year"] = "2018" #add the funding year column
df_2018.head()
# Out:
#       Company Name              Industry Round/Series     Amount   Location  \
# 0  TheCollegeFever       Brand Marketing         Seed   250000.0  Bangalore
# 1      PayMe India    Financial Services        Angel  2000000.0      Noida
# 2         Eunimart  E-Commerce Platforms         Seed        0.0  Hyderabad
# 3           Hasura  Cloud Infrastructure         Seed  1600000.0  Bengaluru
# 4     Freightwalla  Information Services         Seed        0.0     Mumbai
#
#                                        About Company Funding Year
# 0  TheCollegeFever is a hub for fun, fiesta and f...         2018
# 1  PayMe India is an innovative FinTech organizat...         2018
# 2  Eunimart is a one stop solution for merchants ...         2018
# 3  Hasura is a platform that allows developers to...         2018
# 4  Freightwalla is an international forwarder tha...         2018

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    float64
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
#  6   Funding Year   526 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 28.9+ KB

# %%
# Rename Columns of the 2018 data to match the column names of the other data

df_2018 = df_2018.rename(columns = 
                         {'Company Name':'Company/Brand', 'Industry':'Sector', 'Location':'HeadQuarter', 
                          'Round/Series':'Stage', 'Amount':'Amount($)', 'About Company':'What it does'}
                        )
df_2018.head()
# Out:
#      Company/Brand                Sector  Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever       Brand Marketing   Seed   250000.0   Bangalore
# 1      PayMe India    Financial Services  Angel  2000000.0       Noida
# 2         Eunimart  E-Commerce Platforms   Seed        0.0   Hyderabad
# 3           Hasura  Cloud Infrastructure   Seed  1600000.0   Bengaluru
# 4     Freightwalla  Information Services   Seed        0.0      Mumbai
#
#                                         What it does Funding Year
# 0  TheCollegeFever is a hub for fun, fiesta and f...         2018
# 1  PayMe India is an innovative FinTech organizat...         2018
# 2  Eunimart is a one stop solution for merchants ...         2018
# 3  Hasura is a platform that allows developers to...         2018
# 4  Freightwalla is an international forwarder tha...         2018

# %%
#2019 Data
df_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
df_2019["Amount($)"].value_counts()
# Out:
# Undisclosed     12
# $5,000,000       6
# $1,500,000       4
# $6,000,000       4
# $1,000,000       4
# $30,000,000      3
# $20,000,000      3
# $50,000,000      3
# $4,000,000       3
# $5,500,000       3
# $26,000,000      2
# $2,000,000       2
# $12,000,000      2
# $100,000         2
# $5,700,000       1
# $693,000,000     1
# $4,800,000       1
# $120,000,000     1
# $311,000,000     1
# $6,800,000       1
# $36,000,000      1
# $2,800,000       1
# $220,000         1
# $600,000         1
# $7,000,000       1
# $2,100,000       1
# $70,000,000      1
# $60,000,000      1
# $8,000,000       1
# $25,000,000      1
# $6,300,000       1
# $100,000,000     1
# $11,000,000      1
# $28,000,000      1
# $275,000,000     1
# $22,000,000      1
# $140,500         1
# $540,000,000     1
# $15,000,000      1
# $182,700         1
# $15,500,000      1
# $400,000         1
# $2,500,000       1
# $140,000         1
# $230,000,000     1
# $49,400,000      1
# $32,000,000      1
# ...

# %%
#rRemove comas, dashes from the amounts and append Funding year to the data frame
df_2019["Amount($)"] = df_2019["Amount($)"].apply(str)
df_2019["Amount($)"].replace(",","", inplace = True, regex=True)
df_2019["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
df_2019["Amount($)"] = df_2019["Amount($)"].apply(lambda x: float(str(x).replace("$","")))
df_2019["Founded"].replace("nan", np.nan, inplace = True, regex=True)
df_2019["Funding Year"] = "2019"
df_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
#Processing 2020 Dataset
df_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
df_2020 = df_2020.drop("Unnamed: 9", axis = 1)
df_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
df_2020["HeadQuarter"].value_counts().head(50)
# Out:
# Bangalore                                             317
# Mumbai                                                165
# Gurugram                                               79
# Delhi                                                  62
# Chennai                                                43
# Pune                                                   36
# New Delhi                                              36
# Noida                                                  32
# Hyderabad                                              25
# Gurgaon                                                21
# Ahmedabad                                              11
# Kolkata                                                11
# Haryana                                                10
# Indore                                                  8
# Jaipur                                                  6
# Thane                                                   5
# ...

# %%
df_2020["Sector"].value_counts().head(50)
# Out:
# Fintech              80
# Edtech               67
# FinTech              51
# EdTech               40
# E-commerce           33
# Healthtech           28
# SaaS                 24
# Ecommerce            22
# AgriTech             19
# Agritech             19
# Tech                 19
# Media                19
# AI                   18
# Gaming               16
# Logistics            16
# SaaS startup         15
# HealthTech           14
# Tech Startup         14
# AI startup           12
# Food                 12
# Foodtech             12
# Entertainment        12
# Tech company         10
# Healthcare            9
# IoT                   8
# Fashion               7
# Automobile            7
# Cosmetics             7
# Real Estate           6
# Finance               6
# Retail                6
# HealthCare            5
# Transport             5
# Beverage              5
# Logitech              5
# Marketplace           5
# Hospitality           5
# Food Industry         5
# ...

# %%
with pd.option_context('display.max_rows', None):
  print(df_2020)
# Out:
#                               Company/Brand Founded  \
# 0                                Aqgromalin    2019
# 1                                  Krayonnz    2019
# 2                              PadCare Labs    2018
# 3                                     NCOME    2020
# 4                                Gramophone    2016
# 5                                    qZense    2019
# 6                              MyClassboard    2008
# 7                                     Metvy    2018
# 8                                    Rupeek    2015
# 9                                 Gig India    2017
# 10                              Slurrp Farm    2016
# 11                                   Medfin    2017
# 12                                  MasterG    2015
# 13                                 Brila 91    2014
# 14                               FoodyBuddy    2015
# 15                                   Zomato    2008
# 16                                OurEye.ai    2020
# ...

# %%
#make the first values Headquarters, remove $ signs and create 2019 Funding Year column
df_2020['HeadQuarter'] = df_2020['HeadQuarter'].apply(str)
df_2020['HeadQuarter'] = df_2020['HeadQuarter'].str.split(',').str[0]
df_2020['HeadQuarter'] = df_2020['HeadQuarter'].replace("'","",regex=True)

df_2020["Amount($)"] = df_2020["Amount($)"].apply(str)
df_2020["Amount($)"].replace(",","", inplace = True, regex=True)
df_2020["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
df_2020["Amount($)"].replace("Undiclsosed", np.nan, inplace = True, regex=True)
df_2020["Amount($)"].replace("Undislosed", np.nan, inplace = True, regex=True)
df_2020["Amount($)"].replace("nan", np.nan, inplace = True, regex=True)

df_2020["Amount($)"] = df_2020["Amount($)"].apply(lambda x:(str(x).replace("$","")))

df_2020["Funding Year"] = "2020"
df_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
#Replacing the amounts on index 465 and 472 with their avaerage
df_2020["Amount($)"].replace("887000 23000000", "119435500.0", inplace = True, regex=True)
df_2020["Amount($)"].replace("800000000 to 850000000", "825000000.0", inplace = True, regex=True)
df_2020["Amount($)"].loc[465:472]
# Out:
# 465    119435500.0
# 466         764000
# 467         603000
# 468         409000
# 469         292000
# 470         286000
# 471         136000
# 472    825000000.0
# Name: Amount($), dtype: object

# %%
#convert athe datatype in amount to float
df_2020["Amount($)"].astype("float")
# Out:
# 0         200000.0
# 1         100000.0
# 2              NaN
# 3         400000.0
# 4         340000.0
#            ...
# 1050     1500000.0
# 1051    13200000.0
# 1052     8000000.0
# 1053     8043000.0
# 1054     9000000.0
# Name: Amount($), Length: 1055, dtype: float64

# %%
#Processing the 2021 data
df_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
with pd.option_context('display.max_rows', None):
  print(df_2021)
# Out:
#                         Company/Brand  Founded  \
# 0                      Unbox Robotics   2019.0
# 1                              upGrad   2015.0
# 2                         Lead School   2012.0
# 3                             Bizongo   2015.0
# 4                            FypMoney   2021.0
# 5                       Urban Company   2014.0
# 6                      Comofi Medtech   2018.0
# 7                         Qube Health   2016.0
# 8                            Vitra.ai   2020.0
# 9                              Taikee   2010.0
# 10                          Fitterfly   2016.0
# 11                          FreeStand   2017.0
# 12                       MyDentalPlan   2014.0
# 13                       Freyr Energy   2014.0
# 14                          DealShare   2018.0
# 15                           Tessolve   1993.0
# 16                       Smart Joules   2014.0
# 17                               ORAI   2020.0
# 18                            ixamBee   2016.0
# ...

# %%
df_2021.loc[df_2021["Amount($)"] == "ah! Ventures"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 538   Little Leap   2020.0   New Delhi  EdTech
#
#                             What it does  \
# 538  Soft Skills that make Smart Leaders
#
#                                               Founders      Investor  \
# 538  Holistic Development Programs for children in ...  Vishal Gupta
#
#         Amount($)    Stage
# 538  ah! Ventures  $300000

# %%
df_2021.loc[df_2021["Company/Brand"] == "Little Leap", ["Amount($)", "Stage", "Investor"]] = ["$300000", np.nan, "ah! Ventures"]
df_2021.loc[df_2021["Investor"] == "ah! Ventures"]
# Out:
#      Company/Brand  Founded HeadQuarter                             Sector  \
# 356            OwO   2020.0    Gurugram                         E-commerce
# 538    Little Leap   2020.0   New Delhi                             EdTech
# 840      Klassroom   2016.0      Mumbai                             EdTech
# 1133      Enercomp   2013.0   Ahmedabad  Information Technology & Services
#
#                                            What it does  \
# 356   Shop packaged drinking water, beverages from y...
# 538                 Soft Skills that make Smart Leaders
# 840   Klassroom offers a one-of-a-kind LIVE interact...
# 1133  Enercomp Solutions Pvt Ltd provide drone based...
#
#                                                Founders      Investor  \
# 356                                         Hardev Sahu  ah! Ventures
# 538   Holistic Development Programs for children in ...  ah! Ventures
# 840                                         Alka Javeri  ah! Ventures
# ...

# %%
df_2021.loc[df_2021["Amount($)"] == "Pre-series A"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard   2016.0       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders  Investor     Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A
#
#     Stage
# 545   NaN

# %%
df_2021.loc[df_2021["Company/Brand"] == "AdmitKard", ["Amount($)", "Stage", "Investor"]] = ["$1000000", np.nan, "Pre-series A"]
df_2021.loc[df_2021["Company/Brand"] == "AdmitKard"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard   2016.0       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders      Investor Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  Pre-series A  $1000000
#
#     Stage
# 545   NaN

# %%
df_2021.loc[df_2021["Amount($)"] == "ITO Angel Network, LetsVenture"]
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve   2020.0      Mumbai  Human Resources
#
#                                           What it does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor                       Amount($)    Stage
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture  $300000

# %%
df_2021.loc[df_2021["Amount($)"] == "ITO Angel Network, LetsVenture", ["Amount($)", "Stage"]] = ["$300000", np.nan]
df_2021.loc[df_2021["Company/Brand"] == "BHyve"]
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve   2020.0      Mumbai  Human Resources
#
#                                           What it does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor Amount($) Stage
# 551  Omkar Pandharkame, Ketaki Ogale   $300000   NaN

# %%
df_2021.loc[df_2021["Amount($)"] == "JITO Angel Network, LetsVenture"]
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor                        Amount($)     Stage
# 677  Sushil Agarwal  JITO Angel Network, LetsVenture  $1000000

# %%
df_2021.loc[df_2021["Amount($)"] == "JITO Angel Network, LetsVenture", ["Amount($)", "Stage"]] = ["$1000000", np.nan]
df_2021.loc[df_2021["Company/Brand"] == "Saarthi Pedagogy"]
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor Amount($) Stage
# 677  Sushil Agarwal  $1000000   NaN

# %%
df_2021.loc[df_2021["Amount($)"] == "Seed"]
# Out:
#      Company/Brand  Founded      HeadQuarter  \
# 257        MoEVing   2021.0  Gurugram\t#REF!
# 1148     Godamwale   2016.0           Mumbai
#
#                                                  Sector  \
# 257   MoEVing is India's only Electric Mobility focu...
# 1148                           Logistics & Supply Chain
#
#                                            What it does  \
# 257                         Vikash Mishra, Mragank Jain
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                             Founders        Investor  \
# 257   Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000
# 1148       Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#      Amount($) Stage
# 257       Seed   NaN
# 1148      Seed   NaN

# %%
df_2021.loc[df_2021["Company/Brand"] == "MoEVing", ["Amount($)", "Stage", "Investor"]] = ["$5000000", "Seed", np.nan]
df_2021.loc[df_2021["Company/Brand"] == "Godamwale", ["Amount($)", "Stage", "Investor"]] = ["1000000", "Seed", np.nan]
df_2021.loc[df_2021["Company/Brand"] == "MoEVing"]
# Out:
#     Company/Brand  Founded      HeadQuarter  \
# 257       MoEVing   2021.0  Gurugram\t#REF!
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi      NaN  $5000000  Seed

# %%
df_2021.loc[df_2021["Company/Brand"] == "Godamwale"]
# Out:
#      Company/Brand  Founded HeadQuarter                    Sector  \
# 1148     Godamwale   2016.0      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders Investor Amount($) Stage
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan      NaN   1000000  Seed

# %%
df_2021.loc[df_2021["Amount($)"] == "Series C"]
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
df_2021.loc[df_2021["Company/Brand"] == "Fullife Healthcare", ["Amount($)", "Stage", "Investor"]] = ["$22000000000", "Series C", np.nan]
df_2021.drop([256], axis = 0, inplace = True)
df_2021.loc[df_2021["Company/Brand"] == "Fullife Healthcare"]
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders Investor     Amount($)     Stage
# 242  Morgan Stanley Private Equity Asia      NaN  $22000000000  Series C

# %%
df_2021.loc[df_2021["Amount($)"] == "Upsparks"]
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 98        FanPlay   2020.0  Computer Games  Computer Games
# 111       FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What it does Founders  \
# 98   A real money game app specializing in trivia g...   YC W21
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %%
df_2021.loc[df_2021["Company/Brand"] == "FanPlay", ["Amount($)", "Stage", "Investor"]] = ["$1200000", "Upsparks", np.nan]
df_2021.drop([98], axis = 0, inplace = True)
df_2021.loc[df_2021["Company/Brand"] == "FanPlay"]
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 111       FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What it does Founders Investor  \
# 111  A real money game app specializing in trivia g...   YC W21      NaN
#
#     Amount($)     Stage
# 111  $1200000  Upsparks

# %%
#clean Amount column and create Funding year to the data frame
df_2021["Amount($)"] = df_2021["Amount($)"].apply(str)
df_2021["Amount($)"].replace("", 0, inplace = True, regex=True)
df_2021["Amount($)"].replace(",", "", inplace = True, regex=True)
df_2021["Amount($)"].replace("''", "", inplace = True, regex=True)
df_2021["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
df_2021["Amount($)"].replace("undisclosed", np.nan, inplace = True, regex=True)
df_2021["Amount($)"].replace("Undiclsosed", np.nan, inplace = True, regex=True)
df_2021["Amount($)"].replace("Undislosed", np.nan, inplace = True, regex=True)
df_2021["Amount($)"] = df_2021["Amount($)"].apply(lambda x: str(x).replace("$",""))
df_2021["Founded"].replace("nan", np.nan, inplace = True, regex=True)
df_2021["Funding Year"] = "2021"
df_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1207 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1207 non-null   object
#  1   Founded        1206 non-null   float64
#  2   HeadQuarter    1206 non-null   object
#  3   Sector         1207 non-null   object
#  4   What it does   1207 non-null   object
#  5   Founders       1203 non-null   object
#  6   Investor       1141 non-null   object
#  7   Amount($)      1207 non-null   object
#  8   Stage          780 non-null    object
#  9   Funding Year   1207 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 103.7+ KB

# %%
df_2021["Amount($)"].astype(float)
# Out:
# 0         1200000.0
# 1       120000000.0
# 2        30000000.0
# 3        51000000.0
# 4         2000000.0
#            ...
# 1204      3000000.0
# 1205     20000000.0
# 1206     55000000.0
# 1207     26000000.0
# 1208      8000000.0
# Name: Amount($), Length: 1207, dtype: float64

# %% [markdown]
# ## Intergrating/Merging Data

# %%
# Merging Datasets

startup_df = pd.concat([df_2018, df_2019, df_2020, df_2021], ignore_index = True)
startup_df.head()
# Out:
#      Company/Brand                Sector  Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever       Brand Marketing   Seed   250000.0   Bangalore
# 1      PayMe India    Financial Services  Angel  2000000.0       Noida
# 2         Eunimart  E-Commerce Platforms   Seed        0.0   Hyderabad
# 3           Hasura  Cloud Infrastructure   Seed  1600000.0   Bengaluru
# 4     Freightwalla  Information Services   Seed        0.0      Mumbai
#
#                                         What it does Funding Year Founded  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...         2018     NaN
# 1  PayMe India is an innovative FinTech organizat...         2018     NaN
# 2  Eunimart is a one stop solution for merchants ...         2018     NaN
# 3  Hasura is a platform that allows developers to...         2018     NaN
# 4  Freightwalla is an international forwarder tha...         2018     NaN
#
#   Founders Investor
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# ...

# %%
startup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2877 entries, 0 to 2876
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2877 non-null   object
#  1   Sector         2859 non-null   object
#  2   Stage          1940 non-null   object
#  3   Amount($)      2865 non-null   object
#  4   HeadQuarter    2857 non-null   object
#  5   What it does   2877 non-null   object
#  6   Funding Year   2877 non-null   object
#  7   Founded        2109 non-null   object
#  8   Founders       2332 non-null   object
#  9   Investor       2247 non-null   object
# dtypes: object(10)
# memory usage: 224.9+ KB

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ###Amount Column Analysys

# %%
with pd.option_context('display.max_rows', None,):
  print(startup_df)
# Out:
#                                           Company/Brand  \
# 0                                       TheCollegeFever
# 1                                           PayMe India
# 2                                              Eunimart
# 3                                                Hasura
# 4                                          Freightwalla
# 5                                    Microchip Payments
# 6                            BizCrum Infotech Pvt. Ltd.
# 7                                               Emojifi
# 8                                                 Flock
# 9                                             Freshboxx
# 10                           Wide Mobility Mechatronics
# 11                                               Mihuru
# 12                                                 Fyle
# 13                                             AppWharf
# 14                                             Cogoport
# 15                                           PaisaDukan
# ...

# %%
#assess for missing values
startup_df.isna().sum()
# Out:
# Company/Brand      0
# Sector            18
# Stage            937
# Amount($)         12
# HeadQuarter       20
# What it does       0
# Funding Year       0
# Founded          768
# Founders         545
# Investor         630
# dtype: int64

# %%
#replace missing values 
startup_df["Amount($)"].replace(np.NaN, 0, inplace = True)
startup_df.isna().sum()
# Out:
# Company/Brand      0
# Sector            18
# Stage            937
# Amount($)          0
# HeadQuarter       20
# What it does       0
# Funding Year       0
# Founded          768
# Founders         545
# Investor         630
# dtype: int64

# %%
#startup_df["Amount($)"].astype("float")
startup_df["Amount($)"] = startup_df["Amount($)"].astype(float)

# %%
startup_df
# Out:
#         Company/Brand                 Sector         Stage   Amount($)  \
# 0     TheCollegeFever        Brand Marketing          Seed    250000.0
# 1         PayMe India     Financial Services         Angel   2000000.0
# 2            Eunimart   E-Commerce Platforms          Seed         0.0
# 3              Hasura   Cloud Infrastructure          Seed   1600000.0
# 4        Freightwalla   Information Services          Seed         0.0
# ...               ...                    ...           ...         ...
# 2872         Gigforce  Staffing & Recruiting  Pre-series A   3000000.0
# 2873           Vahdam       Food & Beverages      Series D  20000000.0
# 2874     Leap Finance     Financial Services      Series C  55000000.0
# 2875     CollegeDekho                 EdTech      Series B  26000000.0
# 2876           WeRize     Financial Services      Series A   8000000.0
#
#      HeadQuarter                                       What it does  \
# ...

# %%
#check for duplicates
startup_df.duplicated().sum()
# Out:
# 21

# %%
#drop duplicates
startup_df.drop_duplicates(inplace = True)
startup_df.duplicated().sum()
# Out:
# 0

# %%
# Top 10 startup sectors mostly funded in India

# def sector_funding(y='',x=''):
#     top_sector_funding = startup_df.groupby(y)[x].sum().reset_index()
#     top_sector_funding = top_sector_funding.sort_values(by=x, ascending = False)
#     return top_sector_funding

# Top_sector = sector_funding(y= 'Sector', x= 'Amount($)')
# Top_sector

#startup_df.groupby(['Sector'])['Amount($)'].sum()

#startup_df.groupby(['Sector'], sort=True)['Amount($)'].sum()

# fig, ax = plt.subplots(figsize=(10, 5))

# plot = sns.pointplot(
#    ax=ax,
#    data=startup_df, x=startup_df["Sector"], y=startup_df["Amount($)"]
# )
# ax.set_xticklabels([])
# plt.show()

Top_startups_with_fund = startup_df.groupby(['Sector']).count()['Amount($)'].sort_values(ascending=False).reset_index().head(10)
#sns.barplot(y = 'Sector', x = 'Amount($)', data = Top_startups_with_fund)

plt.figure(figsize=(10,8))
plt.title('Top 10 Sectors Funded Most')
ax = sns.barplot(y= 'Sector', x= 'Amount($)', data=Top_startups_with_fund, palette= 'coolwarm')
ax.bar_label(ax.containers[0])
plt.show()

# %%
# Top startup investors by sectors

major_funders = startup_df.groupby('Investor')['Sector'].count().reset_index()
major_funders = major_funders.sort_values(by= 'Sector', ascending = False)
major_funders.head(10)
# Out:
#                        Investor  Sector
# 693   Inflection Point Ventures      35
# 1623          Venture Catalysts      32
# 990       Mumbai Angels Network      17
# 160             Angel investors      15
# 1591                Undisclosed      13
# 1523               Tiger Global      12
# 1547              Titan Capital      11
# 1592     Unicorn India Ventures      10
# 279              Better Capital       9
# 133             Alteria Capital       9

# %%
# Plotting the Top 10 startups with the highest funding by sectors
plt.figure(figsize=(8,6))
plt.title('Major Investors by Number of Sectors')
ax = sns.barplot(y='Investor', x='Sector', data= major_funders.head(10), palette= 'autumn')
ax.bar_label(ax.containers[0])
ax.set(xlabel ="Number of Sectors")
plt.show()

# %%
investor_startup = startup_df.groupby(['Investor', 'Sector'], sort=True).sum().reset_index()
investor_startup = investor_startup.sort_values(by = ['Investor', 'Amount($)'], ascending=True)
investor_startup.head(10)
# Out:
# C:\Users\akoto\AppData\Local\Temp\ipykernel_18328\319418287.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   investor_startup = startup_df.groupby(['Investor', 'Sector'], sort=True).sum().reset_index()
#                                             Investor  \
# 0                                       $Undisclosed
# 1                     01 Advisors, Steadview Capital
# 2                                        021 Capital
# 3                        021 Capital, India Quotient
# 4  021 Capital, Karnataka Information Technology ...
# 5                       021 Capital, Sparrow Capital
# 6                          021 Capital, Y Combinator
# 7                            100X VC, Amara Ventures
# 8  100X.VC﻿,﻿ Titan Capital, Rahul Mathur, Gaurav...
# ...

# %%
# Top startup investors by stages

stage_amount = startup_df.groupby('Stage')['Amount($)'].sum().reset_index()
stage_amount = stage_amount.sort_values(by= 'Amount($)', ascending = False)
stage_amount.head(10)
# Out:
#              Stage     Amount($)
# 6             Debt  1.505874e+11
# 57        Series C  2.746413e+10
# 53        Series B  3.755632e+09
# 59        Series D  3.528002e+09
# 61        Series E  3.430977e+09
# 49        Series A  2.849738e+09
# 67        Series H  2.312500e+09
# 36  Private Equity  2.054000e+09
# 63        Series F  1.703200e+09
# 38            Seed  9.179422e+08

# %%
# Plotting the Top startup stages with the highest funding by sectors
plt.figure(figsize=(8,6))
plt.title('Top Stages by Funding')
ax = sns.barplot(y='Stage', x='Amount($)', data= stage_amount.head(10), palette= 'autumn')
ax.bar_label(ax.containers[0])
ax.set(xlabel ="Funding Amount($)")
plt.show()

# %%
# Top 10 startups with the highest funding by sectors

Top_10_Sectors = startup_df.groupby('Sector')['Amount($)'].sum().reset_index()
Top_10_Sectors = Top_10_Sectors.sort_values(by= 'Amount($)', ascending = False)
Top_10_Sectors.head(10)
# Out:
#                                                 Sector     Amount($)
# 266                                            FinTech  1.538625e+11
# 482                                             Retail  7.054238e+10
# 465  Primary Business is Development and Manufactur...  2.200000e+10
# 225                                             EdTech  3.728504e+09
# 539                                       Tech company  3.022700e+09
# 214                                         E-commerce  2.879052e+09
# 55                                          Automotive  2.250389e+09
# 427                 Multinational conglomerate company  2.200000e+09
# 228                                             Edtech  2.153625e+09
# 269                                 Financial Services  2.080802e+09

# %%
# Plotting the Top 10 startups with the highest funding by sectors
plt.figure(figsize=(8,6))
plt.title('Top 10 Sectors by Startup Funding')
ax = sns.barplot(y='Sector', x='Amount($)', data= Top_10_Sectors.head(10), palette= 'autumn')
ax.bar_label(ax.containers[0])
plt.show()

# %%
# Trend in startup funding in India by year

year_trend = startup_df.groupby('Funding Year')['Amount($)'].sum().reset_index()
year_trend = year_trend.sort_values(by= 'Amount($)', ascending = False)
year_trend.head(10)
# Out:
#   Funding Year     Amount($)
# 3         2021  2.015805e+11
# 2         2020  9.100251e+10
# 0         2018  6.641523e+09
# 1         2019  3.336433e+09

# %%
# Plottig the Trend in startup funding in India by year

sns.relplot(x = startup_df["Funding Year"], y = startup_df["Amount($)"], data = year_trend, kind = "line", errorbar = None)
plt.title('Trend in Funding by Year')
plt.xlabel("Funding Year")
plt.xticks(rotation = 90)
plt.ylabel("Amount($)")
plt.tight_layout()
plt.show()

# %%
# Highly funded sectors by year

year_sector_startup = startup_df.groupby(['Funding Year', 'Sector'], sort=True).sum().reset_index()
year_sector_startup = year_sector_startup.sort_values(by = ['Funding Year', 'Amount($)'], ascending=True)
year_sector_startup
# Out:
# C:\Users\akoto\AppData\Local\Temp\ipykernel_18328\2995799936.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_sector_startup = startup_df.groupby(['Funding Year', 'Sector'], sort=True).sum().reset_index()
#     Funding Year                                             Sector  \
# 0           2018                                        3D Printing
# 7           2018                               Alternative Medicine
# 28          2018                                    Business Travel
# 31          2018                                         Child Care
# 45          2018                              Consumer Applications
# ..           ...                                                ...
# 608         2021                                 Financial Services
# ...

# %%
# Highly funded sectors by year being plotted

sns.relplot(x ="Funding Year", y = "Amount($)", data = year_sector_startup, kind = "line", errorbar = None)
plt.title('Trend in Funding by Year/Sector')
plt.xlabel("Funding Year/Sector")
plt.xticks(rotation = 90)
plt.ylabel("Amount($)")
plt.tight_layout()
plt.show()

# %%
new_df = startup_df.groupby(['Sector', 'Stage'], sort=True).sum().reset_index()
new_df = new_df.sort_values(by = ['Sector', 'Amount($)'], ascending=True)
print(new_df)
# Out:
#            Sector                     Stage   Amount($)
# 0     3D Printing                      Seed         0.0
# 4              AI                Seed Round    160000.0
# 5              AI                Seed round    220000.0
# 3              AI                      Seed   1500000.0
# 2              AI              Pre series A   1600000.0
# ...           ...                       ...         ...
# 1030            —           Corporate Round   5096000.0
# 1031            —            Debt Financing   8030000.0
# 1033            —                      Seed   9277320.0
# 1035            —                  Series B  14000000.0
# 1036            —  Venture - Series Unknown  15380000.0
#
# [1037 rows x 3 columns]
# ...

# %%
# Top 10 locations with highest startup funding in India

Top_10_Locations = startup_df.groupby('HeadQuarter')['Amount($)'].sum().reset_index()
Top_10_Locations = Top_10_Locations.sort_values(by= 'Amount($)', ascending = False)
Top_10_Locations.head(10)
# Out:
#                 HeadQuarter     Amount($)
# 76                   Mumbai  2.315080e+11
# 9                 Bangalore  2.384487e+10
# 91   Pharmaceuticals\t#REF!  2.200000e+10
# 43                 Gurugram  5.667667e+09
# 79                New Delhi  3.421521e+09
# 21               California  3.078300e+09
# 133                     nan  1.467761e+09
# 94                     Pune  1.395939e+09
# 42                  Gurgaon  1.388756e+09
# 23                  Chennai  1.123976e+09

# %%
# Bar plot for the top 10 locations with highest startup funding in India

plt.figure(figsize=(8,6))
plt.title('Top 10 Locations Getting Startup Funding')
ax = sns.barplot(y='HeadQuarter', x='Amount($)', data= Top_10_Locations.head(10), palette= 'autumn')
ax.bar_label(ax.containers[0])
plt.show()
# Out:
# C:\Users\akoto\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
